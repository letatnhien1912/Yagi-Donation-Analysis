# %%
import pandas as pd
from tabula import read_pdf
from PyPDF2 import PdfFileReader

# %% [markdown]
# #### **VietinBank Statement**

# %%
# Read Vietinbank statement file
vtb_path = 'data/VietinBank.pdf'
vtb = read_pdf(vtb_path, pages='all') # As there are only over 2000 pages so we can read them all at once

# %%
vtb_full = vtb[0].copy()
vtb_full.columns = vtb_full.iloc[0,:]
vtb_full.drop(index=[0,2], axis=0, inplace=True)
vtb_full = vtb_full.loc[:, vtb_full.columns.notna()]
vtb_full.dropna(axis=0, how='all', inplace=True)

for i in range(1,len(vtb)):
    vtb[i].loc[len(vtb[i])] = vtb[i].columns.values
    vtb[i].columns = vtb_full.columns
    vtb_full = pd.concat([vtb_full, vtb[i]], ignore_index=True)
    print(f'Concatnated {i+1} files.')
# Out:
# Concatnated 2 files.
# Concatnated 3 files.
# Concatnated 4 files.
# Concatnated 5 files.
# Concatnated 6 files.
# Concatnated 7 files.
# Concatnated 8 files.
# Concatnated 9 files.
# Concatnated 10 files.
# Concatnated 11 files.
# Concatnated 12 files.
# Concatnated 13 files.
# Concatnated 14 files.
# Concatnated 15 files.
# Concatnated 16 files.
# Concatnated 17 files.
# Concatnated 18 files.
# Concatnated 19 files.
# Concatnated 20 files.
# Concatnated 21 files.
# Concatnated 22 files.
# Concatnated 23 files.
# Concatnated 24 files.
# Concatnated 25 files.
# Concatnated 26 files.
# Concatnated 27 files.
# Concatnated 28 files.
# Concatnated 29 files.
# Concatnated 30 files.
# Concatnated 31 files.
# Concatnated 32 files.
# Concatnated 33 files.
# Concatnated 34 files.
# Concatnated 35 files.
# Concatnated 36 files.
# Concatnated 37 files.
# Concatnated 38 files.
# Concatnated 39 files.
# Concatnated 40 files.
# Concatnated 41 files.
# Concatnated 42 files.
# Concatnated 43 files.
# Concatnated 44 files.
# Concatnated 45 files.
# Concatnated 46 files.
# Concatnated 47 files.
# Concatnated 48 files.
# Concatnated 49 files.
# Concatnated 50 files.
# Concatnated 51 files.
# Concatnated 52 files.
# Concatnated 53 files.
# Concatnated 54 files.
# Concatnated 55 files.
# Concatnated 56 files.
# Concatnated 57 files.
# Concatnated 58 files.
# Concatnated 59 files.
# Concatnated 60 files.
# Concatnated 61 files.
# Concatnated 62 files.
# Concatnated 63 files.
# Concatnated 64 files.
# Concatnated 65 files.
# Concatnated 66 files.
# Concatnated 67 files.
# Concatnated 68 files.
# Concatnated 69 files.
# Concatnated 70 files.
# Concatnated 71 files.
# Concatnated 72 files.
# Concatnated 73 files.
# Concatnated 74 files.
# Concatnated 75 files.
# Concatnated 76 files.
# Concatnated 77 files.
# Concatnated 78 files.
# Concatnated 79 files.
# Concatnated 80 files.
# Concatnated 81 files.
# Concatnated 82 files.
# Concatnated 83 files.
# Concatnated 84 files.
# Concatnated 85 files.
# Concatnated 86 files.
# Concatnated 87 files.
# Concatnated 88 files.
# Concatnated 89 files.
# Concatnated 90 files.
# Concatnated 91 files.
# Concatnated 92 files.
# Concatnated 93 files.
# Concatnated 94 files.
# Concatnated 95 files.
# Concatnated 96 files.
# Concatnated 97 files.
# Concatnated 98 files.
# Concatnated 99 files.
# Concatnated 100 files.
# Concatnated 101 files.
# Concatnated 102 files.
# Concatnated 103 files.
# Concatnated 104 files.
# Concatnated 105 files.
# Concatnated 106 files.
# Concatnated 107 files.
# Concatnated 108 files.
# Concatnated 109 files.
# Concatnated 110 files.
# Concatnated 111 files.
# Concatnated 112 files.
# Concatnated 113 files.
# Concatnated 114 files.
# Concatnated 115 files.
# Concatnated 116 files.
# Concatnated 117 files.
# Concatnated 118 files.
# Concatnated 119 files.
# Concatnated 120 files.
# Concatnated 121 files.
# Concatnated 122 files.
# Concatnated 123 files.
# Concatnated 124 files.
# Concatnated 125 files.
# Concatnated 126 files.
# Concatnated 127 files.
# Concatnated 128 files.
# Concatnated 129 files.
# Concatnated 130 files.
# Concatnated 131 files.
# Concatnated 132 files.
# Concatnated 133 files.
# Concatnated 134 files.
# Concatnated 135 files.
# Concatnated 136 files.
# Concatnated 137 files.
# Concatnated 138 files.
# Concatnated 139 files.
# Concatnated 140 files.
# Concatnated 141 files.
# Concatnated 142 files.
# Concatnated 143 files.
# Concatnated 144 files.
# Concatnated 145 files.
# Concatnated 146 files.
# Concatnated 147 files.
# Concatnated 148 files.
# Concatnated 149 files.
# Concatnated 150 files.
# Concatnated 151 files.
# Concatnated 152 files.
# Concatnated 153 files.
# Concatnated 154 files.
# Concatnated 155 files.
# Concatnated 156 files.
# Concatnated 157 files.
# Concatnated 158 files.
# Concatnated 159 files.
# Concatnated 160 files.
# Concatnated 161 files.
# Concatnated 162 files.
# Concatnated 163 files.
# Concatnated 164 files.
# Concatnated 165 files.
# Concatnated 166 files.
# Concatnated 167 files.
# Concatnated 168 files.
# Concatnated 169 files.
# Concatnated 170 files.
# Concatnated 171 files.
# Concatnated 172 files.
# Concatnated 173 files.
# Concatnated 174 files.
# Concatnated 175 files.
# Concatnated 176 files.
# Concatnated 177 files.
# Concatnated 178 files.
# Concatnated 179 files.
# Concatnated 180 files.
# Concatnated 181 files.
# Concatnated 182 files.
# Concatnated 183 files.
# Concatnated 184 files.
# Concatnated 185 files.
# Concatnated 186 files.
# Concatnated 187 files.
# Concatnated 188 files.
# Concatnated 189 files.
# Concatnated 190 files.
# Concatnated 191 files.
# Concatnated 192 files.
# Concatnated 193 files.
# Concatnated 194 files.
# Concatnated 195 files.
# Concatnated 196 files.
# Concatnated 197 files.
# Concatnated 198 files.
# Concatnated 199 files.
# Concatnated 200 files.
# Concatnated 201 files.
# Concatnated 202 files.
# Concatnated 203 files.
# Concatnated 204 files.
# Concatnated 205 files.
# Concatnated 206 files.
# Concatnated 207 files.
# Concatnated 208 files.
# Concatnated 209 files.
# Concatnated 210 files.
# Concatnated 211 files.
# Concatnated 212 files.
# Concatnated 213 files.
# Concatnated 214 files.
# Concatnated 215 files.
# Concatnated 216 files.
# Concatnated 217 files.
# Concatnated 218 files.
# Concatnated 219 files.
# Concatnated 220 files.
# Concatnated 221 files.
# Concatnated 222 files.
# Concatnated 223 files.
# Concatnated 224 files.
# Concatnated 225 files.
# Concatnated 226 files.
# Concatnated 227 files.
# Concatnated 228 files.
# Concatnated 229 files.
# Concatnated 230 files.
# Concatnated 231 files.
# Concatnated 232 files.
# Concatnated 233 files.
# Concatnated 234 files.
# Concatnated 235 files.
# Concatnated 236 files.
# Concatnated 237 files.
# Concatnated 238 files.
# Concatnated 239 files.
# Concatnated 240 files.
# Concatnated 241 files.
# Concatnated 242 files.
# Concatnated 243 files.
# Concatnated 244 files.
# Concatnated 245 files.
# Concatnated 246 files.
# Concatnated 247 files.
# Concatnated 248 files.
# Concatnated 249 files.
# Concatnated 250 files.
# Concatnated 251 files.
# Concatnated 252 files.
# Concatnated 253 files.
# Concatnated 254 files.
# Concatnated 255 files.
# Concatnated 256 files.
# Concatnated 257 files.
# Concatnated 258 files.
# Concatnated 259 files.
# Concatnated 260 files.
# Concatnated 261 files.
# Concatnated 262 files.
# Concatnated 263 files.
# Concatnated 264 files.
# Concatnated 265 files.
# Concatnated 266 files.
# Concatnated 267 files.
# Concatnated 268 files.
# Concatnated 269 files.
# Concatnated 270 files.
# Concatnated 271 files.
# Concatnated 272 files.
# Concatnated 273 files.
# Concatnated 274 files.
# Concatnated 275 files.
# Concatnated 276 files.
# Concatnated 277 files.
# Concatnated 278 files.
# Concatnated 279 files.
# Concatnated 280 files.
# Concatnated 281 files.
# Concatnated 282 files.
# Concatnated 283 files.
# Concatnated 284 files.
# Concatnated 285 files.
# Concatnated 286 files.
# Concatnated 287 files.
# Concatnated 288 files.
# Concatnated 289 files.
# Concatnated 290 files.
# Concatnated 291 files.
# Concatnated 292 files.
# Concatnated 293 files.
# Concatnated 294 files.
# Concatnated 295 files.
# Concatnated 296 files.
# Concatnated 297 files.
# Concatnated 298 files.
# Concatnated 299 files.
# Concatnated 300 files.
# Concatnated 301 files.
# Concatnated 302 files.
# Concatnated 303 files.
# Concatnated 304 files.
# Concatnated 305 files.
# Concatnated 306 files.
# Concatnated 307 files.
# Concatnated 308 files.
# Concatnated 309 files.
# Concatnated 310 files.
# Concatnated 311 files.
# Concatnated 312 files.
# Concatnated 313 files.
# Concatnated 314 files.
# Concatnated 315 files.
# Concatnated 316 files.
# Concatnated 317 files.
# Concatnated 318 files.
# Concatnated 319 files.
# Concatnated 320 files.
# Concatnated 321 files.
# Concatnated 322 files.
# Concatnated 323 files.
# Concatnated 324 files.
# Concatnated 325 files.
# Concatnated 326 files.
# Concatnated 327 files.
# Concatnated 328 files.
# Concatnated 329 files.
# Concatnated 330 files.
# Concatnated 331 files.
# Concatnated 332 files.
# Concatnated 333 files.
# Concatnated 334 files.
# Concatnated 335 files.
# Concatnated 336 files.
# Concatnated 337 files.
# Concatnated 338 files.
# Concatnated 339 files.
# Concatnated 340 files.
# Concatnated 341 files.
# Concatnated 342 files.
# Concatnated 343 files.
# Concatnated 344 files.
# Concatnated 345 files.
# Concatnated 346 files.
# Concatnated 347 files.
# Concatnated 348 files.
# Concatnated 349 files.
# Concatnated 350 files.
# Concatnated 351 files.
# Concatnated 352 files.
# Concatnated 353 files.
# Concatnated 354 files.
# Concatnated 355 files.
# Concatnated 356 files.
# Concatnated 357 files.
# Concatnated 358 files.
# Concatnated 359 files.
# Concatnated 360 files.
# Concatnated 361 files.
# Concatnated 362 files.
# Concatnated 363 files.
# Concatnated 364 files.
# Concatnated 365 files.
# Concatnated 366 files.
# Concatnated 367 files.
# Concatnated 368 files.
# Concatnated 369 files.
# Concatnated 370 files.
# Concatnated 371 files.
# Concatnated 372 files.
# Concatnated 373 files.
# Concatnated 374 files.
# Concatnated 375 files.
# Concatnated 376 files.
# Concatnated 377 files.
# Concatnated 378 files.
# Concatnated 379 files.
# Concatnated 380 files.
# Concatnated 381 files.
# Concatnated 382 files.
# Concatnated 383 files.
# Concatnated 384 files.
# Concatnated 385 files.
# Concatnated 386 files.
# Concatnated 387 files.
# Concatnated 388 files.
# Concatnated 389 files.
# Concatnated 390 files.
# Concatnated 391 files.
# Concatnated 392 files.
# Concatnated 393 files.
# Concatnated 394 files.
# Concatnated 395 files.
# Concatnated 396 files.
# Concatnated 397 files.
# Concatnated 398 files.
# Concatnated 399 files.
# Concatnated 400 files.
# Concatnated 401 files.
# Concatnated 402 files.
# Concatnated 403 files.
# Concatnated 404 files.
# Concatnated 405 files.
# Concatnated 406 files.
# Concatnated 407 files.
# Concatnated 408 files.
# Concatnated 409 files.
# Concatnated 410 files.
# Concatnated 411 files.
# Concatnated 412 files.
# Concatnated 413 files.
# Concatnated 414 files.
# Concatnated 415 files.
# Concatnated 416 files.
# Concatnated 417 files.
# Concatnated 418 files.
# Concatnated 419 files.
# Concatnated 420 files.
# Concatnated 421 files.
# Concatnated 422 files.
# Concatnated 423 files.
# Concatnated 424 files.
# Concatnated 425 files.
# Concatnated 426 files.
# Concatnated 427 files.
# Concatnated 428 files.
# Concatnated 429 files.
# Concatnated 430 files.
# Concatnated 431 files.
# Concatnated 432 files.
# Concatnated 433 files.
# Concatnated 434 files.
# Concatnated 435 files.
# Concatnated 436 files.
# Concatnated 437 files.
# Concatnated 438 files.
# Concatnated 439 files.
# Concatnated 440 files.
# Concatnated 441 files.
# Concatnated 442 files.
# Concatnated 443 files.
# Concatnated 444 files.
# Concatnated 445 files.
# Concatnated 446 files.
# Concatnated 447 files.
# Concatnated 448 files.
# Concatnated 449 files.
# Concatnated 450 files.
# Concatnated 451 files.
# Concatnated 452 files.
# Concatnated 453 files.
# Concatnated 454 files.
# Concatnated 455 files.
# Concatnated 456 files.
# Concatnated 457 files.
# Concatnated 458 files.
# Concatnated 459 files.
# Concatnated 460 files.
# Concatnated 461 files.
# Concatnated 462 files.
# Concatnated 463 files.
# Concatnated 464 files.
# Concatnated 465 files.
# Concatnated 466 files.
# Concatnated 467 files.
# Concatnated 468 files.
# Concatnated 469 files.
# Concatnated 470 files.
# Concatnated 471 files.
# Concatnated 472 files.
# Concatnated 473 files.
# Concatnated 474 files.
# Concatnated 475 files.
# Concatnated 476 files.
# Concatnated 477 files.
# Concatnated 478 files.
# Concatnated 479 files.
# Concatnated 480 files.
# Concatnated 481 files.
# Concatnated 482 files.
# Concatnated 483 files.
# Concatnated 484 files.
# Concatnated 485 files.
# Concatnated 486 files.
# Concatnated 487 files.
# Concatnated 488 files.
# Concatnated 489 files.
# Concatnated 490 files.
# Concatnated 491 files.
# Concatnated 492 files.
# Concatnated 493 files.
# Concatnated 494 files.
# Concatnated 495 files.
# Concatnated 496 files.
# Concatnated 497 files.
# Concatnated 498 files.
# Concatnated 499 files.
# Concatnated 500 files.
# Concatnated 501 files.
# Concatnated 502 files.
# Concatnated 503 files.
# Concatnated 504 files.
# Concatnated 505 files.
# Concatnated 506 files.
# Concatnated 507 files.
# Concatnated 508 files.
# Concatnated 509 files.
# Concatnated 510 files.
# Concatnated 511 files.
# Concatnated 512 files.
# Concatnated 513 files.
# Concatnated 514 files.
# Concatnated 515 files.
# Concatnated 516 files.
# Concatnated 517 files.
# Concatnated 518 files.
# Concatnated 519 files.
# Concatnated 520 files.
# Concatnated 521 files.
# Concatnated 522 files.
# Concatnated 523 files.
# Concatnated 524 files.
# Concatnated 525 files.
# Concatnated 526 files.
# Concatnated 527 files.
# Concatnated 528 files.
# Concatnated 529 files.
# Concatnated 530 files.
# Concatnated 531 files.
# Concatnated 532 files.
# Concatnated 533 files.
# Concatnated 534 files.
# Concatnated 535 files.
# Concatnated 536 files.
# Concatnated 537 files.
# Concatnated 538 files.
# Concatnated 539 files.
# Concatnated 540 files.
# Concatnated 541 files.
# Concatnated 542 files.
# Concatnated 543 files.
# Concatnated 544 files.
# Concatnated 545 files.
# Concatnated 546 files.
# Concatnated 547 files.
# Concatnated 548 files.
# Concatnated 549 files.
# Concatnated 550 files.
# Concatnated 551 files.
# Concatnated 552 files.
# Concatnated 553 files.
# Concatnated 554 files.
# Concatnated 555 files.
# Concatnated 556 files.
# Concatnated 557 files.
# Concatnated 558 files.
# Concatnated 559 files.
# Concatnated 560 files.
# Concatnated 561 files.
# Concatnated 562 files.
# Concatnated 563 files.
# Concatnated 564 files.
# Concatnated 565 files.
# Concatnated 566 files.
# Concatnated 567 files.
# Concatnated 568 files.
# Concatnated 569 files.
# Concatnated 570 files.
# Concatnated 571 files.
# Concatnated 572 files.
# Concatnated 573 files.
# Concatnated 574 files.
# Concatnated 575 files.
# Concatnated 576 files.
# Concatnated 577 files.
# Concatnated 578 files.
# Concatnated 579 files.
# Concatnated 580 files.
# Concatnated 581 files.
# Concatnated 582 files.
# Concatnated 583 files.
# Concatnated 584 files.
# Concatnated 585 files.
# Concatnated 586 files.
# Concatnated 587 files.
# Concatnated 588 files.
# Concatnated 589 files.
# Concatnated 590 files.
# Concatnated 591 files.
# Concatnated 592 files.
# Concatnated 593 files.
# Concatnated 594 files.
# Concatnated 595 files.
# Concatnated 596 files.
# Concatnated 597 files.
# Concatnated 598 files.
# Concatnated 599 files.
# Concatnated 600 files.
# Concatnated 601 files.
# Concatnated 602 files.
# Concatnated 603 files.
# Concatnated 604 files.
# Concatnated 605 files.
# Concatnated 606 files.
# Concatnated 607 files.
# Concatnated 608 files.
# Concatnated 609 files.
# Concatnated 610 files.
# Concatnated 611 files.
# Concatnated 612 files.
# Concatnated 613 files.
# Concatnated 614 files.
# Concatnated 615 files.
# Concatnated 616 files.
# Concatnated 617 files.
# Concatnated 618 files.
# Concatnated 619 files.
# Concatnated 620 files.
# Concatnated 621 files.
# Concatnated 622 files.
# Concatnated 623 files.
# Concatnated 624 files.
# Concatnated 625 files.
# Concatnated 626 files.
# Concatnated 627 files.
# Concatnated 628 files.
# Concatnated 629 files.
# Concatnated 630 files.
# Concatnated 631 files.
# Concatnated 632 files.
# Concatnated 633 files.
# Concatnated 634 files.
# Concatnated 635 files.
# Concatnated 636 files.
# Concatnated 637 files.
# Concatnated 638 files.
# Concatnated 639 files.
# Concatnated 640 files.
# Concatnated 641 files.
# Concatnated 642 files.
# Concatnated 643 files.
# Concatnated 644 files.
# Concatnated 645 files.
# Concatnated 646 files.
# Concatnated 647 files.
# Concatnated 648 files.
# Concatnated 649 files.
# Concatnated 650 files.
# Concatnated 651 files.
# Concatnated 652 files.
# Concatnated 653 files.
# Concatnated 654 files.
# Concatnated 655 files.
# Concatnated 656 files.
# Concatnated 657 files.
# Concatnated 658 files.
# Concatnated 659 files.
# Concatnated 660 files.
# Concatnated 661 files.
# Concatnated 662 files.
# Concatnated 663 files.
# Concatnated 664 files.
# Concatnated 665 files.
# Concatnated 666 files.
# Concatnated 667 files.
# Concatnated 668 files.
# Concatnated 669 files.
# Concatnated 670 files.
# Concatnated 671 files.
# Concatnated 672 files.
# Concatnated 673 files.
# Concatnated 674 files.
# Concatnated 675 files.
# Concatnated 676 files.
# Concatnated 677 files.
# Concatnated 678 files.
# Concatnated 679 files.
# Concatnated 680 files.
# Concatnated 681 files.
# Concatnated 682 files.
# Concatnated 683 files.
# Concatnated 684 files.
# Concatnated 685 files.
# Concatnated 686 files.
# Concatnated 687 files.
# Concatnated 688 files.
# Concatnated 689 files.
# Concatnated 690 files.
# Concatnated 691 files.
# Concatnated 692 files.
# Concatnated 693 files.
# Concatnated 694 files.
# Concatnated 695 files.
# Concatnated 696 files.
# Concatnated 697 files.
# Concatnated 698 files.
# Concatnated 699 files.
# Concatnated 700 files.
# Concatnated 701 files.
# Concatnated 702 files.
# Concatnated 703 files.
# Concatnated 704 files.
# Concatnated 705 files.
# Concatnated 706 files.
# Concatnated 707 files.
# Concatnated 708 files.
# Concatnated 709 files.
# Concatnated 710 files.
# Concatnated 711 files.
# Concatnated 712 files.
# Concatnated 713 files.
# Concatnated 714 files.
# Concatnated 715 files.
# Concatnated 716 files.
# Concatnated 717 files.
# Concatnated 718 files.
# Concatnated 719 files.
# Concatnated 720 files.
# Concatnated 721 files.
# Concatnated 722 files.
# Concatnated 723 files.
# Concatnated 724 files.
# Concatnated 725 files.
# Concatnated 726 files.
# Concatnated 727 files.
# Concatnated 728 files.
# Concatnated 729 files.
# Concatnated 730 files.
# Concatnated 731 files.
# Concatnated 732 files.
# Concatnated 733 files.
# Concatnated 734 files.
# Concatnated 735 files.
# Concatnated 736 files.
# Concatnated 737 files.
# Concatnated 738 files.
# Concatnated 739 files.
# Concatnated 740 files.
# Concatnated 741 files.
# Concatnated 742 files.
# Concatnated 743 files.
# Concatnated 744 files.
# Concatnated 745 files.
# Concatnated 746 files.
# Concatnated 747 files.
# Concatnated 748 files.
# Concatnated 749 files.
# Concatnated 750 files.
# Concatnated 751 files.
# Concatnated 752 files.
# Concatnated 753 files.
# Concatnated 754 files.
# Concatnated 755 files.
# Concatnated 756 files.
# Concatnated 757 files.
# Concatnated 758 files.
# Concatnated 759 files.
# Concatnated 760 files.
# Concatnated 761 files.
# Concatnated 762 files.
# Concatnated 763 files.
# Concatnated 764 files.
# Concatnated 765 files.
# Concatnated 766 files.
# Concatnated 767 files.
# Concatnated 768 files.
# Concatnated 769 files.
# Concatnated 770 files.
# Concatnated 771 files.
# Concatnated 772 files.
# Concatnated 773 files.
# Concatnated 774 files.
# Concatnated 775 files.
# Concatnated 776 files.
# Concatnated 777 files.
# Concatnated 778 files.
# Concatnated 779 files.
# Concatnated 780 files.
# Concatnated 781 files.
# Concatnated 782 files.
# Concatnated 783 files.
# Concatnated 784 files.
# Concatnated 785 files.
# Concatnated 786 files.
# Concatnated 787 files.
# Concatnated 788 files.
# Concatnated 789 files.
# Concatnated 790 files.
# Concatnated 791 files.
# Concatnated 792 files.
# Concatnated 793 files.
# Concatnated 794 files.
# Concatnated 795 files.
# Concatnated 796 files.
# Concatnated 797 files.
# Concatnated 798 files.
# Concatnated 799 files.
# Concatnated 800 files.
# Concatnated 801 files.
# Concatnated 802 files.
# Concatnated 803 files.
# Concatnated 804 files.
# Concatnated 805 files.
# Concatnated 806 files.
# Concatnated 807 files.
# Concatnated 808 files.
# Concatnated 809 files.
# Concatnated 810 files.
# Concatnated 811 files.
# Concatnated 812 files.
# Concatnated 813 files.
# Concatnated 814 files.
# Concatnated 815 files.
# Concatnated 816 files.
# Concatnated 817 files.
# Concatnated 818 files.
# Concatnated 819 files.
# Concatnated 820 files.
# Concatnated 821 files.
# Concatnated 822 files.
# Concatnated 823 files.
# Concatnated 824 files.
# Concatnated 825 files.
# Concatnated 826 files.
# Concatnated 827 files.
# Concatnated 828 files.
# Concatnated 829 files.
# Concatnated 830 files.
# Concatnated 831 files.
# Concatnated 832 files.
# Concatnated 833 files.
# Concatnated 834 files.
# Concatnated 835 files.
# Concatnated 836 files.
# Concatnated 837 files.
# Concatnated 838 files.
# Concatnated 839 files.
# Concatnated 840 files.
# Concatnated 841 files.
# Concatnated 842 files.
# Concatnated 843 files.
# Concatnated 844 files.
# Concatnated 845 files.
# Concatnated 846 files.
# Concatnated 847 files.
# Concatnated 848 files.
# Concatnated 849 files.
# Concatnated 850 files.
# Concatnated 851 files.
# Concatnated 852 files.
# Concatnated 853 files.
# Concatnated 854 files.
# Concatnated 855 files.
# Concatnated 856 files.
# Concatnated 857 files.
# Concatnated 858 files.
# Concatnated 859 files.
# Concatnated 860 files.
# Concatnated 861 files.
# Concatnated 862 files.
# Concatnated 863 files.
# Concatnated 864 files.
# Concatnated 865 files.
# Concatnated 866 files.
# Concatnated 867 files.
# Concatnated 868 files.
# Concatnated 869 files.
# Concatnated 870 files.
# Concatnated 871 files.
# Concatnated 872 files.
# Concatnated 873 files.
# Concatnated 874 files.
# Concatnated 875 files.
# Concatnated 876 files.
# Concatnated 877 files.
# Concatnated 878 files.
# Concatnated 879 files.
# Concatnated 880 files.
# Concatnated 881 files.
# Concatnated 882 files.
# Concatnated 883 files.
# Concatnated 884 files.
# Concatnated 885 files.
# Concatnated 886 files.
# Concatnated 887 files.
# Concatnated 888 files.
# Concatnated 889 files.
# Concatnated 890 files.
# Concatnated 891 files.
# Concatnated 892 files.
# Concatnated 893 files.
# Concatnated 894 files.
# Concatnated 895 files.
# Concatnated 896 files.
# Concatnated 897 files.
# Concatnated 898 files.
# Concatnated 899 files.
# Concatnated 900 files.
# Concatnated 901 files.
# Concatnated 902 files.
# Concatnated 903 files.
# Concatnated 904 files.
# Concatnated 905 files.
# Concatnated 906 files.
# Concatnated 907 files.
# Concatnated 908 files.
# Concatnated 909 files.
# Concatnated 910 files.
# Concatnated 911 files.
# Concatnated 912 files.
# Concatnated 913 files.
# Concatnated 914 files.
# Concatnated 915 files.
# Concatnated 916 files.
# Concatnated 917 files.
# Concatnated 918 files.
# Concatnated 919 files.
# Concatnated 920 files.
# Concatnated 921 files.
# Concatnated 922 files.
# Concatnated 923 files.
# Concatnated 924 files.
# Concatnated 925 files.
# Concatnated 926 files.
# Concatnated 927 files.
# Concatnated 928 files.
# Concatnated 929 files.
# Concatnated 930 files.
# Concatnated 931 files.
# Concatnated 932 files.
# Concatnated 933 files.
# Concatnated 934 files.
# Concatnated 935 files.
# Concatnated 936 files.
# Concatnated 937 files.
# Concatnated 938 files.
# Concatnated 939 files.
# Concatnated 940 files.
# Concatnated 941 files.
# Concatnated 942 files.
# Concatnated 943 files.
# Concatnated 944 files.
# Concatnated 945 files.
# Concatnated 946 files.
# Concatnated 947 files.
# Concatnated 948 files.
# Concatnated 949 files.
# Concatnated 950 files.
# Concatnated 951 files.
# Concatnated 952 files.
# Concatnated 953 files.
# Concatnated 954 files.
# Concatnated 955 files.
# Concatnated 956 files.
# Concatnated 957 files.
# Concatnated 958 files.
# Concatnated 959 files.
# Concatnated 960 files.
# Concatnated 961 files.
# Concatnated 962 files.
# Concatnated 963 files.
# Concatnated 964 files.
# Concatnated 965 files.
# Concatnated 966 files.
# Concatnated 967 files.
# Concatnated 968 files.
# Concatnated 969 files.
# Concatnated 970 files.
# Concatnated 971 files.
# Concatnated 972 files.
# Concatnated 973 files.
# Concatnated 974 files.
# Concatnated 975 files.
# Concatnated 976 files.
# Concatnated 977 files.
# Concatnated 978 files.
# Concatnated 979 files.
# Concatnated 980 files.
# Concatnated 981 files.
# Concatnated 982 files.
# Concatnated 983 files.
# Concatnated 984 files.
# Concatnated 985 files.
# Concatnated 986 files.
# Concatnated 987 files.
# Concatnated 988 files.
# Concatnated 989 files.
# Concatnated 990 files.
# Concatnated 991 files.
# Concatnated 992 files.
# Concatnated 993 files.
# Concatnated 994 files.
# Concatnated 995 files.
# Concatnated 996 files.
# Concatnated 997 files.
# Concatnated 998 files.
# Concatnated 999 files.
# Concatnated 1000 files.
# Concatnated 1001 files.
# Concatnated 1002 files.
# Concatnated 1003 files.
# Concatnated 1004 files.
# Concatnated 1005 files.
# Concatnated 1006 files.
# Concatnated 1007 files.
# Concatnated 1008 files.
# Concatnated 1009 files.
# Concatnated 1010 files.
# Concatnated 1011 files.
# Concatnated 1012 files.
# Concatnated 1013 files.
# Concatnated 1014 files.
# Concatnated 1015 files.
# Concatnated 1016 files.
# Concatnated 1017 files.
# Concatnated 1018 files.
# Concatnated 1019 files.
# Concatnated 1020 files.
# Concatnated 1021 files.
# Concatnated 1022 files.
# Concatnated 1023 files.
# Concatnated 1024 files.
# Concatnated 1025 files.
# Concatnated 1026 files.
# Concatnated 1027 files.
# Concatnated 1028 files.
# Concatnated 1029 files.
# Concatnated 1030 files.
# Concatnated 1031 files.
# Concatnated 1032 files.
# Concatnated 1033 files.
# Concatnated 1034 files.
# Concatnated 1035 files.
# Concatnated 1036 files.
# Concatnated 1037 files.
# Concatnated 1038 files.
# Concatnated 1039 files.
# Concatnated 1040 files.
# Concatnated 1041 files.
# Concatnated 1042 files.
# Concatnated 1043 files.
# Concatnated 1044 files.
# Concatnated 1045 files.
# Concatnated 1046 files.
# Concatnated 1047 files.
# Concatnated 1048 files.
# Concatnated 1049 files.
# Concatnated 1050 files.
# Concatnated 1051 files.
# Concatnated 1052 files.
# Concatnated 1053 files.
# Concatnated 1054 files.
# Concatnated 1055 files.
# Concatnated 1056 files.
# Concatnated 1057 files.
# Concatnated 1058 files.
# Concatnated 1059 files.
# Concatnated 1060 files.
# Concatnated 1061 files.
# Concatnated 1062 files.
# Concatnated 1063 files.
# Concatnated 1064 files.
# Concatnated 1065 files.
# Concatnated 1066 files.
# Concatnated 1067 files.
# Concatnated 1068 files.
# Concatnated 1069 files.
# Concatnated 1070 files.
# Concatnated 1071 files.
# Concatnated 1072 files.
# Concatnated 1073 files.
# Concatnated 1074 files.
# Concatnated 1075 files.
# Concatnated 1076 files.
# Concatnated 1077 files.
# Concatnated 1078 files.
# Concatnated 1079 files.
# Concatnated 1080 files.
# Concatnated 1081 files.
# Concatnated 1082 files.
# Concatnated 1083 files.
# Concatnated 1084 files.
# Concatnated 1085 files.
# Concatnated 1086 files.
# Concatnated 1087 files.
# Concatnated 1088 files.
# Concatnated 1089 files.
# Concatnated 1090 files.
# Concatnated 1091 files.
# Concatnated 1092 files.
# Concatnated 1093 files.
# Concatnated 1094 files.
# Concatnated 1095 files.
# Concatnated 1096 files.
# Concatnated 1097 files.
# Concatnated 1098 files.
# Concatnated 1099 files.
# Concatnated 1100 files.
# Concatnated 1101 files.
# Concatnated 1102 files.
# Concatnated 1103 files.
# Concatnated 1104 files.
# Concatnated 1105 files.
# Concatnated 1106 files.
# Concatnated 1107 files.
# Concatnated 1108 files.
# Concatnated 1109 files.
# Concatnated 1110 files.
# Concatnated 1111 files.
# Concatnated 1112 files.
# Concatnated 1113 files.
# Concatnated 1114 files.
# Concatnated 1115 files.
# Concatnated 1116 files.
# Concatnated 1117 files.
# Concatnated 1118 files.
# Concatnated 1119 files.
# Concatnated 1120 files.
# Concatnated 1121 files.
# Concatnated 1122 files.
# Concatnated 1123 files.
# Concatnated 1124 files.
# Concatnated 1125 files.
# Concatnated 1126 files.
# Concatnated 1127 files.
# Concatnated 1128 files.
# Concatnated 1129 files.
# Concatnated 1130 files.
# Concatnated 1131 files.
# Concatnated 1132 files.
# Concatnated 1133 files.
# Concatnated 1134 files.
# Concatnated 1135 files.
# Concatnated 1136 files.
# Concatnated 1137 files.
# Concatnated 1138 files.
# Concatnated 1139 files.
# Concatnated 1140 files.
# Concatnated 1141 files.
# Concatnated 1142 files.
# Concatnated 1143 files.
# Concatnated 1144 files.
# Concatnated 1145 files.
# Concatnated 1146 files.
# Concatnated 1147 files.
# Concatnated 1148 files.
# Concatnated 1149 files.
# Concatnated 1150 files.
# Concatnated 1151 files.
# Concatnated 1152 files.
# Concatnated 1153 files.
# Concatnated 1154 files.
# Concatnated 1155 files.
# Concatnated 1156 files.
# Concatnated 1157 files.
# Concatnated 1158 files.
# Concatnated 1159 files.
# Concatnated 1160 files.
# Concatnated 1161 files.
# Concatnated 1162 files.
# Concatnated 1163 files.
# Concatnated 1164 files.
# Concatnated 1165 files.
# Concatnated 1166 files.
# Concatnated 1167 files.
# Concatnated 1168 files.
# Concatnated 1169 files.
# Concatnated 1170 files.
# Concatnated 1171 files.
# Concatnated 1172 files.
# Concatnated 1173 files.
# Concatnated 1174 files.
# Concatnated 1175 files.
# Concatnated 1176 files.
# Concatnated 1177 files.
# Concatnated 1178 files.
# Concatnated 1179 files.
# Concatnated 1180 files.
# Concatnated 1181 files.
# Concatnated 1182 files.
# Concatnated 1183 files.
# Concatnated 1184 files.
# Concatnated 1185 files.
# Concatnated 1186 files.
# Concatnated 1187 files.
# Concatnated 1188 files.
# Concatnated 1189 files.
# Concatnated 1190 files.
# Concatnated 1191 files.
# Concatnated 1192 files.
# Concatnated 1193 files.
# Concatnated 1194 files.
# Concatnated 1195 files.
# Concatnated 1196 files.
# Concatnated 1197 files.
# Concatnated 1198 files.
# Concatnated 1199 files.
# Concatnated 1200 files.
# Concatnated 1201 files.
# Concatnated 1202 files.
# Concatnated 1203 files.
# Concatnated 1204 files.
# Concatnated 1205 files.
# Concatnated 1206 files.
# Concatnated 1207 files.
# Concatnated 1208 files.
# Concatnated 1209 files.
# Concatnated 1210 files.
# Concatnated 1211 files.
# Concatnated 1212 files.
# Concatnated 1213 files.
# Concatnated 1214 files.
# Concatnated 1215 files.
# Concatnated 1216 files.
# Concatnated 1217 files.
# Concatnated 1218 files.
# Concatnated 1219 files.
# Concatnated 1220 files.
# Concatnated 1221 files.
# Concatnated 1222 files.
# Concatnated 1223 files.
# Concatnated 1224 files.
# Concatnated 1225 files.
# Concatnated 1226 files.
# Concatnated 1227 files.
# Concatnated 1228 files.
# Concatnated 1229 files.
# Concatnated 1230 files.
# Concatnated 1231 files.
# Concatnated 1232 files.
# Concatnated 1233 files.
# Concatnated 1234 files.
# Concatnated 1235 files.
# Concatnated 1236 files.
# Concatnated 1237 files.
# Concatnated 1238 files.
# Concatnated 1239 files.
# Concatnated 1240 files.
# Concatnated 1241 files.
# Concatnated 1242 files.
# Concatnated 1243 files.
# Concatnated 1244 files.
# Concatnated 1245 files.
# Concatnated 1246 files.
# Concatnated 1247 files.
# Concatnated 1248 files.
# Concatnated 1249 files.
# Concatnated 1250 files.
# Concatnated 1251 files.
# Concatnated 1252 files.
# Concatnated 1253 files.
# Concatnated 1254 files.
# Concatnated 1255 files.
# Concatnated 1256 files.
# Concatnated 1257 files.
# Concatnated 1258 files.
# Concatnated 1259 files.
# Concatnated 1260 files.
# Concatnated 1261 files.
# Concatnated 1262 files.
# Concatnated 1263 files.
# Concatnated 1264 files.
# Concatnated 1265 files.
# Concatnated 1266 files.
# Concatnated 1267 files.
# Concatnated 1268 files.
# Concatnated 1269 files.
# Concatnated 1270 files.
# Concatnated 1271 files.
# Concatnated 1272 files.
# Concatnated 1273 files.
# Concatnated 1274 files.
# Concatnated 1275 files.
# Concatnated 1276 files.
# Concatnated 1277 files.
# Concatnated 1278 files.
# Concatnated 1279 files.
# Concatnated 1280 files.
# Concatnated 1281 files.
# Concatnated 1282 files.
# Concatnated 1283 files.
# Concatnated 1284 files.
# Concatnated 1285 files.
# Concatnated 1286 files.
# Concatnated 1287 files.
# Concatnated 1288 files.
# Concatnated 1289 files.
# Concatnated 1290 files.
# Concatnated 1291 files.
# Concatnated 1292 files.
# Concatnated 1293 files.
# Concatnated 1294 files.
# Concatnated 1295 files.
# Concatnated 1296 files.
# Concatnated 1297 files.
# Concatnated 1298 files.
# Concatnated 1299 files.
# Concatnated 1300 files.
# Concatnated 1301 files.
# Concatnated 1302 files.
# Concatnated 1303 files.
# Concatnated 1304 files.
# Concatnated 1305 files.
# Concatnated 1306 files.
# Concatnated 1307 files.
# Concatnated 1308 files.
# Concatnated 1309 files.
# Concatnated 1310 files.
# Concatnated 1311 files.
# Concatnated 1312 files.
# Concatnated 1313 files.
# Concatnated 1314 files.
# Concatnated 1315 files.
# Concatnated 1316 files.
# Concatnated 1317 files.
# Concatnated 1318 files.
# Concatnated 1319 files.
# Concatnated 1320 files.
# Concatnated 1321 files.
# Concatnated 1322 files.
# Concatnated 1323 files.
# Concatnated 1324 files.
# Concatnated 1325 files.
# Concatnated 1326 files.
# Concatnated 1327 files.
# Concatnated 1328 files.
# Concatnated 1329 files.
# Concatnated 1330 files.
# Concatnated 1331 files.
# Concatnated 1332 files.
# Concatnated 1333 files.
# Concatnated 1334 files.
# Concatnated 1335 files.
# Concatnated 1336 files.
# Concatnated 1337 files.
# Concatnated 1338 files.
# Concatnated 1339 files.
# Concatnated 1340 files.
# Concatnated 1341 files.
# Concatnated 1342 files.
# Concatnated 1343 files.
# Concatnated 1344 files.
# Concatnated 1345 files.
# Concatnated 1346 files.
# Concatnated 1347 files.
# Concatnated 1348 files.
# Concatnated 1349 files.
# Concatnated 1350 files.
# Concatnated 1351 files.
# Concatnated 1352 files.
# Concatnated 1353 files.
# Concatnated 1354 files.
# Concatnated 1355 files.
# Concatnated 1356 files.
# Concatnated 1357 files.
# Concatnated 1358 files.
# Concatnated 1359 files.
# Concatnated 1360 files.
# Concatnated 1361 files.
# Concatnated 1362 files.
# Concatnated 1363 files.
# Concatnated 1364 files.
# Concatnated 1365 files.
# Concatnated 1366 files.
# Concatnated 1367 files.
# Concatnated 1368 files.
# Concatnated 1369 files.
# Concatnated 1370 files.
# Concatnated 1371 files.
# Concatnated 1372 files.
# Concatnated 1373 files.
# Concatnated 1374 files.
# Concatnated 1375 files.
# Concatnated 1376 files.
# Concatnated 1377 files.
# Concatnated 1378 files.
# Concatnated 1379 files.
# Concatnated 1380 files.
# Concatnated 1381 files.
# Concatnated 1382 files.
# Concatnated 1383 files.
# Concatnated 1384 files.
# Concatnated 1385 files.
# Concatnated 1386 files.
# Concatnated 1387 files.
# Concatnated 1388 files.
# Concatnated 1389 files.
# Concatnated 1390 files.
# Concatnated 1391 files.
# Concatnated 1392 files.
# Concatnated 1393 files.
# Concatnated 1394 files.
# Concatnated 1395 files.
# Concatnated 1396 files.
# Concatnated 1397 files.
# Concatnated 1398 files.
# Concatnated 1399 files.
# Concatnated 1400 files.
# Concatnated 1401 files.
# Concatnated 1402 files.
# Concatnated 1403 files.
# Concatnated 1404 files.
# Concatnated 1405 files.
# Concatnated 1406 files.
# Concatnated 1407 files.
# Concatnated 1408 files.
# Concatnated 1409 files.
# Concatnated 1410 files.
# Concatnated 1411 files.
# Concatnated 1412 files.
# Concatnated 1413 files.
# Concatnated 1414 files.
# Concatnated 1415 files.
# Concatnated 1416 files.
# Concatnated 1417 files.
# Concatnated 1418 files.
# Concatnated 1419 files.
# Concatnated 1420 files.
# Concatnated 1421 files.
# Concatnated 1422 files.
# Concatnated 1423 files.
# Concatnated 1424 files.
# Concatnated 1425 files.
# Concatnated 1426 files.
# Concatnated 1427 files.
# Concatnated 1428 files.
# Concatnated 1429 files.
# Concatnated 1430 files.
# Concatnated 1431 files.
# Concatnated 1432 files.
# Concatnated 1433 files.
# Concatnated 1434 files.
# Concatnated 1435 files.
# Concatnated 1436 files.
# Concatnated 1437 files.
# Concatnated 1438 files.
# Concatnated 1439 files.
# Concatnated 1440 files.
# Concatnated 1441 files.
# Concatnated 1442 files.
# Concatnated 1443 files.
# Concatnated 1444 files.
# Concatnated 1445 files.
# Concatnated 1446 files.
# Concatnated 1447 files.
# Concatnated 1448 files.
# Concatnated 1449 files.
# Concatnated 1450 files.
# Concatnated 1451 files.
# Concatnated 1452 files.
# Concatnated 1453 files.
# Concatnated 1454 files.
# Concatnated 1455 files.
# Concatnated 1456 files.
# Concatnated 1457 files.
# Concatnated 1458 files.
# Concatnated 1459 files.
# Concatnated 1460 files.
# Concatnated 1461 files.
# Concatnated 1462 files.
# Concatnated 1463 files.
# Concatnated 1464 files.
# Concatnated 1465 files.
# Concatnated 1466 files.
# Concatnated 1467 files.
# Concatnated 1468 files.
# Concatnated 1469 files.
# Concatnated 1470 files.
# Concatnated 1471 files.
# Concatnated 1472 files.
# Concatnated 1473 files.
# Concatnated 1474 files.
# Concatnated 1475 files.
# Concatnated 1476 files.
# Concatnated 1477 files.
# Concatnated 1478 files.
# Concatnated 1479 files.
# Concatnated 1480 files.
# Concatnated 1481 files.
# Concatnated 1482 files.
# Concatnated 1483 files.
# Concatnated 1484 files.
# Concatnated 1485 files.
# Concatnated 1486 files.
# Concatnated 1487 files.
# Concatnated 1488 files.
# Concatnated 1489 files.
# Concatnated 1490 files.
# Concatnated 1491 files.
# Concatnated 1492 files.
# Concatnated 1493 files.
# Concatnated 1494 files.
# Concatnated 1495 files.
# Concatnated 1496 files.
# Concatnated 1497 files.
# Concatnated 1498 files.
# Concatnated 1499 files.
# Concatnated 1500 files.
# Concatnated 1501 files.
# Concatnated 1502 files.
# Concatnated 1503 files.
# Concatnated 1504 files.
# Concatnated 1505 files.
# Concatnated 1506 files.
# Concatnated 1507 files.
# Concatnated 1508 files.
# Concatnated 1509 files.
# Concatnated 1510 files.
# Concatnated 1511 files.
# Concatnated 1512 files.
# Concatnated 1513 files.
# Concatnated 1514 files.
# Concatnated 1515 files.
# Concatnated 1516 files.
# Concatnated 1517 files.
# Concatnated 1518 files.
# Concatnated 1519 files.
# Concatnated 1520 files.
# Concatnated 1521 files.
# Concatnated 1522 files.
# Concatnated 1523 files.
# Concatnated 1524 files.
# Concatnated 1525 files.
# Concatnated 1526 files.
# Concatnated 1527 files.
# Concatnated 1528 files.
# Concatnated 1529 files.
# Concatnated 1530 files.
# Concatnated 1531 files.
# Concatnated 1532 files.
# Concatnated 1533 files.
# Concatnated 1534 files.
# Concatnated 1535 files.
# Concatnated 1536 files.
# Concatnated 1537 files.
# Concatnated 1538 files.
# Concatnated 1539 files.
# Concatnated 1540 files.
# Concatnated 1541 files.
# Concatnated 1542 files.
# Concatnated 1543 files.
# Concatnated 1544 files.
# Concatnated 1545 files.
# Concatnated 1546 files.
# Concatnated 1547 files.
# Concatnated 1548 files.
# Concatnated 1549 files.
# Concatnated 1550 files.
# Concatnated 1551 files.
# Concatnated 1552 files.
# Concatnated 1553 files.
# Concatnated 1554 files.
# Concatnated 1555 files.
# Concatnated 1556 files.
# Concatnated 1557 files.
# Concatnated 1558 files.
# Concatnated 1559 files.
# Concatnated 1560 files.
# Concatnated 1561 files.
# Concatnated 1562 files.
# Concatnated 1563 files.
# Concatnated 1564 files.
# Concatnated 1565 files.
# Concatnated 1566 files.
# Concatnated 1567 files.
# Concatnated 1568 files.
# Concatnated 1569 files.
# Concatnated 1570 files.
# Concatnated 1571 files.
# Concatnated 1572 files.
# Concatnated 1573 files.
# Concatnated 1574 files.
# Concatnated 1575 files.
# Concatnated 1576 files.
# Concatnated 1577 files.
# Concatnated 1578 files.
# Concatnated 1579 files.
# Concatnated 1580 files.
# Concatnated 1581 files.
# Concatnated 1582 files.
# Concatnated 1583 files.
# Concatnated 1584 files.
# Concatnated 1585 files.
# Concatnated 1586 files.
# Concatnated 1587 files.
# Concatnated 1588 files.
# Concatnated 1589 files.
# Concatnated 1590 files.
# Concatnated 1591 files.
# Concatnated 1592 files.
# Concatnated 1593 files.
# Concatnated 1594 files.
# Concatnated 1595 files.
# Concatnated 1596 files.
# Concatnated 1597 files.
# Concatnated 1598 files.
# Concatnated 1599 files.
# Concatnated 1600 files.
# Concatnated 1601 files.
# Concatnated 1602 files.
# Concatnated 1603 files.
# Concatnated 1604 files.
# Concatnated 1605 files.
# Concatnated 1606 files.
# Concatnated 1607 files.
# Concatnated 1608 files.
# Concatnated 1609 files.
# Concatnated 1610 files.
# Concatnated 1611 files.
# Concatnated 1612 files.
# Concatnated 1613 files.
# Concatnated 1614 files.
# Concatnated 1615 files.
# Concatnated 1616 files.
# Concatnated 1617 files.
# Concatnated 1618 files.
# Concatnated 1619 files.
# Concatnated 1620 files.
# Concatnated 1621 files.
# Concatnated 1622 files.
# Concatnated 1623 files.
# Concatnated 1624 files.
# Concatnated 1625 files.
# Concatnated 1626 files.
# Concatnated 1627 files.
# Concatnated 1628 files.
# Concatnated 1629 files.
# Concatnated 1630 files.
# Concatnated 1631 files.
# Concatnated 1632 files.
# Concatnated 1633 files.
# Concatnated 1634 files.
# Concatnated 1635 files.
# Concatnated 1636 files.
# Concatnated 1637 files.
# Concatnated 1638 files.
# Concatnated 1639 files.
# Concatnated 1640 files.
# Concatnated 1641 files.
# Concatnated 1642 files.
# Concatnated 1643 files.
# Concatnated 1644 files.
# Concatnated 1645 files.
# Concatnated 1646 files.
# Concatnated 1647 files.
# Concatnated 1648 files.
# Concatnated 1649 files.
# Concatnated 1650 files.
# Concatnated 1651 files.
# Concatnated 1652 files.
# Concatnated 1653 files.
# Concatnated 1654 files.
# Concatnated 1655 files.
# Concatnated 1656 files.
# Concatnated 1657 files.
# Concatnated 1658 files.
# Concatnated 1659 files.
# Concatnated 1660 files.
# Concatnated 1661 files.
# Concatnated 1662 files.
# Concatnated 1663 files.
# Concatnated 1664 files.
# Concatnated 1665 files.
# Concatnated 1666 files.
# Concatnated 1667 files.
# Concatnated 1668 files.
# Concatnated 1669 files.
# Concatnated 1670 files.
# Concatnated 1671 files.
# Concatnated 1672 files.
# Concatnated 1673 files.
# Concatnated 1674 files.
# Concatnated 1675 files.
# Concatnated 1676 files.
# Concatnated 1677 files.
# Concatnated 1678 files.
# Concatnated 1679 files.
# Concatnated 1680 files.
# Concatnated 1681 files.
# Concatnated 1682 files.
# Concatnated 1683 files.
# Concatnated 1684 files.
# Concatnated 1685 files.
# Concatnated 1686 files.
# Concatnated 1687 files.
# Concatnated 1688 files.
# Concatnated 1689 files.
# Concatnated 1690 files.
# Concatnated 1691 files.
# Concatnated 1692 files.
# Concatnated 1693 files.
# Concatnated 1694 files.
# Concatnated 1695 files.
# Concatnated 1696 files.
# Concatnated 1697 files.
# Concatnated 1698 files.
# Concatnated 1699 files.
# Concatnated 1700 files.
# Concatnated 1701 files.
# Concatnated 1702 files.
# Concatnated 1703 files.
# Concatnated 1704 files.
# Concatnated 1705 files.
# Concatnated 1706 files.
# Concatnated 1707 files.
# Concatnated 1708 files.
# Concatnated 1709 files.
# Concatnated 1710 files.
# Concatnated 1711 files.
# Concatnated 1712 files.
# Concatnated 1713 files.
# Concatnated 1714 files.
# Concatnated 1715 files.
# Concatnated 1716 files.
# Concatnated 1717 files.
# Concatnated 1718 files.
# Concatnated 1719 files.
# Concatnated 1720 files.
# Concatnated 1721 files.
# Concatnated 1722 files.
# Concatnated 1723 files.
# Concatnated 1724 files.
# Concatnated 1725 files.
# Concatnated 1726 files.
# Concatnated 1727 files.
# Concatnated 1728 files.
# Concatnated 1729 files.
# Concatnated 1730 files.
# Concatnated 1731 files.
# Concatnated 1732 files.
# Concatnated 1733 files.
# Concatnated 1734 files.
# Concatnated 1735 files.
# Concatnated 1736 files.
# Concatnated 1737 files.
# Concatnated 1738 files.
# Concatnated 1739 files.
# Concatnated 1740 files.
# Concatnated 1741 files.
# Concatnated 1742 files.
# Concatnated 1743 files.
# Concatnated 1744 files.
# Concatnated 1745 files.
# Concatnated 1746 files.
# Concatnated 1747 files.
# Concatnated 1748 files.
# Concatnated 1749 files.
# Concatnated 1750 files.
# Concatnated 1751 files.
# Concatnated 1752 files.
# Concatnated 1753 files.
# Concatnated 1754 files.
# Concatnated 1755 files.
# Concatnated 1756 files.
# Concatnated 1757 files.
# Concatnated 1758 files.
# Concatnated 1759 files.
# Concatnated 1760 files.
# Concatnated 1761 files.
# Concatnated 1762 files.
# Concatnated 1763 files.
# Concatnated 1764 files.
# Concatnated 1765 files.
# Concatnated 1766 files.
# Concatnated 1767 files.
# Concatnated 1768 files.
# Concatnated 1769 files.
# Concatnated 1770 files.
# Concatnated 1771 files.
# Concatnated 1772 files.
# Concatnated 1773 files.
# Concatnated 1774 files.
# Concatnated 1775 files.
# Concatnated 1776 files.
# Concatnated 1777 files.
# Concatnated 1778 files.
# Concatnated 1779 files.
# Concatnated 1780 files.
# Concatnated 1781 files.
# Concatnated 1782 files.
# Concatnated 1783 files.
# Concatnated 1784 files.
# Concatnated 1785 files.
# Concatnated 1786 files.
# Concatnated 1787 files.
# Concatnated 1788 files.
# Concatnated 1789 files.
# Concatnated 1790 files.
# Concatnated 1791 files.
# Concatnated 1792 files.
# Concatnated 1793 files.
# Concatnated 1794 files.
# Concatnated 1795 files.
# Concatnated 1796 files.
# Concatnated 1797 files.
# Concatnated 1798 files.
# Concatnated 1799 files.
# Concatnated 1800 files.
# Concatnated 1801 files.
# Concatnated 1802 files.
# Concatnated 1803 files.
# Concatnated 1804 files.
# Concatnated 1805 files.
# Concatnated 1806 files.
# Concatnated 1807 files.
# Concatnated 1808 files.
# Concatnated 1809 files.
# Concatnated 1810 files.
# Concatnated 1811 files.
# Concatnated 1812 files.
# Concatnated 1813 files.
# Concatnated 1814 files.
# Concatnated 1815 files.
# Concatnated 1816 files.
# Concatnated 1817 files.
# Concatnated 1818 files.
# Concatnated 1819 files.
# Concatnated 1820 files.
# Concatnated 1821 files.
# Concatnated 1822 files.
# Concatnated 1823 files.
# Concatnated 1824 files.
# Concatnated 1825 files.
# Concatnated 1826 files.
# Concatnated 1827 files.
# Concatnated 1828 files.
# Concatnated 1829 files.
# Concatnated 1830 files.
# Concatnated 1831 files.
# Concatnated 1832 files.
# Concatnated 1833 files.
# Concatnated 1834 files.
# Concatnated 1835 files.
# Concatnated 1836 files.
# Concatnated 1837 files.
# Concatnated 1838 files.
# Concatnated 1839 files.
# Concatnated 1840 files.
# Concatnated 1841 files.
# Concatnated 1842 files.
# Concatnated 1843 files.
# Concatnated 1844 files.
# Concatnated 1845 files.
# Concatnated 1846 files.
# Concatnated 1847 files.
# Concatnated 1848 files.
# Concatnated 1849 files.
# Concatnated 1850 files.
# Concatnated 1851 files.
# Concatnated 1852 files.
# Concatnated 1853 files.
# Concatnated 1854 files.
# Concatnated 1855 files.
# Concatnated 1856 files.
# Concatnated 1857 files.
# Concatnated 1858 files.
# Concatnated 1859 files.
# Concatnated 1860 files.
# Concatnated 1861 files.
# Concatnated 1862 files.
# Concatnated 1863 files.
# Concatnated 1864 files.
# Concatnated 1865 files.
# Concatnated 1866 files.
# Concatnated 1867 files.
# Concatnated 1868 files.
# Concatnated 1869 files.
# Concatnated 1870 files.
# Concatnated 1871 files.
# Concatnated 1872 files.
# Concatnated 1873 files.
# Concatnated 1874 files.
# Concatnated 1875 files.
# Concatnated 1876 files.
# Concatnated 1877 files.
# Concatnated 1878 files.
# Concatnated 1879 files.
# Concatnated 1880 files.
# Concatnated 1881 files.
# Concatnated 1882 files.
# Concatnated 1883 files.
# Concatnated 1884 files.
# Concatnated 1885 files.
# Concatnated 1886 files.
# Concatnated 1887 files.
# Concatnated 1888 files.
# Concatnated 1889 files.
# Concatnated 1890 files.
# Concatnated 1891 files.
# Concatnated 1892 files.
# Concatnated 1893 files.
# Concatnated 1894 files.
# Concatnated 1895 files.
# Concatnated 1896 files.
# Concatnated 1897 files.
# Concatnated 1898 files.
# Concatnated 1899 files.
# Concatnated 1900 files.
# Concatnated 1901 files.
# Concatnated 1902 files.
# Concatnated 1903 files.
# Concatnated 1904 files.
# Concatnated 1905 files.
# Concatnated 1906 files.
# Concatnated 1907 files.
# Concatnated 1908 files.
# Concatnated 1909 files.
# Concatnated 1910 files.
# Concatnated 1911 files.
# Concatnated 1912 files.
# Concatnated 1913 files.
# Concatnated 1914 files.
# Concatnated 1915 files.
# Concatnated 1916 files.
# Concatnated 1917 files.
# Concatnated 1918 files.
# Concatnated 1919 files.
# Concatnated 1920 files.
# Concatnated 1921 files.
# Concatnated 1922 files.
# Concatnated 1923 files.
# Concatnated 1924 files.
# Concatnated 1925 files.
# Concatnated 1926 files.
# Concatnated 1927 files.
# Concatnated 1928 files.
# Concatnated 1929 files.
# Concatnated 1930 files.
# Concatnated 1931 files.
# Concatnated 1932 files.
# Concatnated 1933 files.
# Concatnated 1934 files.
# Concatnated 1935 files.
# Concatnated 1936 files.
# Concatnated 1937 files.
# Concatnated 1938 files.
# Concatnated 1939 files.
# Concatnated 1940 files.
# Concatnated 1941 files.
# Concatnated 1942 files.
# Concatnated 1943 files.
# Concatnated 1944 files.
# Concatnated 1945 files.
# Concatnated 1946 files.
# Concatnated 1947 files.
# Concatnated 1948 files.
# Concatnated 1949 files.
# Concatnated 1950 files.
# Concatnated 1951 files.
# Concatnated 1952 files.
# Concatnated 1953 files.
# Concatnated 1954 files.
# Concatnated 1955 files.
# Concatnated 1956 files.
# Concatnated 1957 files.
# Concatnated 1958 files.
# Concatnated 1959 files.
# Concatnated 1960 files.
# Concatnated 1961 files.
# Concatnated 1962 files.
# Concatnated 1963 files.
# Concatnated 1964 files.
# Concatnated 1965 files.
# Concatnated 1966 files.
# Concatnated 1967 files.
# Concatnated 1968 files.
# Concatnated 1969 files.
# Concatnated 1970 files.
# Concatnated 1971 files.
# Concatnated 1972 files.
# Concatnated 1973 files.
# Concatnated 1974 files.
# Concatnated 1975 files.
# Concatnated 1976 files.
# Concatnated 1977 files.
# Concatnated 1978 files.
# Concatnated 1979 files.
# Concatnated 1980 files.
# Concatnated 1981 files.
# Concatnated 1982 files.
# Concatnated 1983 files.
# Concatnated 1984 files.
# Concatnated 1985 files.
# Concatnated 1986 files.
# Concatnated 1987 files.
# Concatnated 1988 files.
# Concatnated 1989 files.
# Concatnated 1990 files.
# Concatnated 1991 files.
# Concatnated 1992 files.
# Concatnated 1993 files.
# Concatnated 1994 files.
# Concatnated 1995 files.
# Concatnated 1996 files.
# Concatnated 1997 files.
# Concatnated 1998 files.
# Concatnated 1999 files.
# Concatnated 2000 files.
# Concatnated 2001 files.
# Concatnated 2002 files.
# Concatnated 2003 files.
# Concatnated 2004 files.
# Concatnated 2005 files.
# Concatnated 2006 files.
# Concatnated 2007 files.
# Concatnated 2008 files.
# Concatnated 2009 files.

# %%
vtb_full.head()
# Out:
# 0 STT               Ngày GD  \
# 0   1  10/09/2024\r12:01:29
# 1   2  10/09/2024\r12:01:46
# 2   3  10/09/2024\r13:33:47
# 3   4  10/09/2024\r13:34:31
# 4   5  10/09/2024\r13:37:09
#
# 0                                    Mô tả giao dịch  Số tiền  \
# 0  CT nhanh 247 den: TRAN TIEN ANH chuyen\rtien u...  300.000
# 1     CT nhanh 247 den: Phuong Quynh Le chuyen\rtien  100.000
# 2        TRAN TRONG SON Chuyen tien ung ho\r(CT1111)  100.000
# 3       NGUYEN THU BINH chuyen tien ung ho\r(CT1111)  100.000
# 4  Chuyen tien den tu NAPAS Noi dung: NGUYEN\rTHU...  100.000
#
# 0                     Tên đối ứng
# 0             TRAN TIEN ANH – A/C
# 1           LE PHUONG QUYNH – A/C
# 2            TRAN TRONG SON – A/C
# 3           NGUYEN THU BINH – A/C
# 4  VND-TGTT-NGUYEN THU BINH – A/C

# %%
vtb_full.set_index(keys='STT', inplace=True)

# define lambda function to remove '\r' in string
string_clean = lambda x: str(x).replace('\r', ' ')

# clean and transform the columns
vtb_full.loc[:, 'Ngày GD'] = pd.to_datetime(vtb_full['Ngày GD'].apply(string_clean), format='%d/%m/%Y %H:%M:%S')
vtb_full.loc[:, 'Mô tả giao dịch'] = vtb_full['Mô tả giao dịch'].apply(string_clean)
vtb_full.loc[:, 'Tên đối ứng'] = vtb_full['Mô tả giao dịch'].apply(string_clean)
vtb_full.loc[:, 'Số tiền'] = vtb_full['Số tiền'].apply(lambda x: int(str(x).replace('.','')))

# %%
# Save the output to a csv file
vtb_full.to_csv('data/VietinBank_statement.csv')

# %% [markdown]
# #### **VietcomBank Account Bank Statement**

# %%
vcb_path = 'data/VietcomBank.pdf'

# Test reading VietcomBank statements file
vcb_test = read_pdf(vcb_path, pages=1, stream=True) # As the tables in the file are borderless, setting stream=True helps focus on text alignment
vcb_test[0].head(10)
# Out:
#         Ngày GD/       Unnamed: 0       Unnamed: 1 Unnamed: 2  \
# 0            NaN  Số tiền ghi nợ/  Số tiền ghi có/     Số dư/
# 1       TNX Date              NaN              NaN        NaN
# 2            NaN            Debit           Credit    Balance
# 3  Số CT/ Doc No              NaN              NaN        NaN
# 4     01/09/2024              NaN              NaN        NaN
# 5            NaN              NaN           50.000        NaN
# 6     5213.45946              NaN              NaN        NaN
# 7     01/09/2024              NaN              NaN        NaN
# 8            NaN              NaN           20.000        NaN
# 9     5090.85797              NaN              NaN        NaN
#
#                               Unnamed: 3
# 0                     Nội dung chi tiết/
# 1                                    NaN
# 2                 Transactions in detail
# 3                                    NaN
# 4                                    NaN
# 5        292976.010924.013647.xin cam on
# 6                                    NaN
# 7                                    NaN
# 8  VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu
# 9                                    NaN

# %%
# Clean the data in batches as the pdf file has over 12 thousand pages

def count_pdf_pages(file_path):
    """Function returns the number of pages in a pdf file"""
    with open(file_path, 'rb') as file:
        reader = PdfFileReader(file)
        return reader.numPages
    
def cleaning_vcb(df: pd.DataFrame):
    # skip the first 4 rows of headers
    df = df[4:]

    # rename and drop unnecessary columns
    df.columns = ['transaction_date', 'debit', 'credit', 'balance', 'detail']
    df = df.drop(['debit', 'balance'], axis=1)

    # add column 'transaction_no'
    cleaned_df = pd.DataFrame(columns= df.columns.insert(0, 'transaction_no'))

    # set variables for each column value
    _date = _transactionNo = _credit = None
    _detail = [] # set list as a transaction detail may have multiple rows
    row_count = 0

    for _, row in df.iterrows():
        transaction_date, credit, detail = row
        if pd.notna(transaction_date):
            if '/' in transaction_date:
                # Append row to df and reset the variables when reaching a date value in column 'Ngày GD'
                if _transactionNo and _date and _credit and _transactionNo:
                    cleaned_df.loc[row_count] = [_transactionNo, _date, _credit, ' '.join(_detail)]
                    _date = _transactionNo = _credit = None
                    _detail = []
                    row_count += 1

                _date = transaction_date
            elif '.' in transaction_date:
                _transactionNo = transaction_date
        
        if pd.notna(credit):
            _credit = credit

        if pd.notna(detail):
            _detail.append(detail)

    # Handling the last transaction after the loop
    if _transactionNo and _date and _credit:
        cleaned_df.loc[row_count] = [_transactionNo, _date, _credit, ' '.join(_detail)]

    return cleaned_df

# Loop through each 500 pages to clean and concatnate the full dataframe
vcb_full = pd.DataFrame()

num_pages = count_pdf_pages(vcb_path)
per_pages = 500
loops = num_pages // per_pages

for i in range(loops + 1):

    from_page = per_pages * i + 1
    to_page = (per_pages * (i + 1)) if i <= loops else (from_page + (num_pages % per_pages) - 1) # Handling the remaining pages in the last loop
    print(f'\nStart reading from page {from_page} to page {to_page}...')
    vcb = read_pdf(vcb_path, pages=list(range(from_page, to_page + 1)), stream=True)

    for page in range(len(vcb)):
        cleanned_df = cleaning_vcb(vcb[page])
        vcb_full = pd.concat([vcb_full, cleanned_df], ignore_index=True)
        print(f'Concatnated {page + from_page} pages.')

# Save the output to a csv file
vcb_full.to_csv('data/Vietcombank_statement.csv', index=False)
